# %% [markdown]
# # Get SOC-OCV curves at -20, -10, 0, 10, 25, 40 °C

# %%
from plotData import plotData
from cellData import cellData
from cellExtractOCV import cellExtractOCV

# %%
pathname = '../dataset/LG-18650HG2/'
files_name = ['0degC/585_C20DisCh.csv',
              '10degC/575_C20DisCh.csv',
              '25degC/549_C20DisCh.csv',
              '40degC/555_C20DisCh.csv',
              'n10degC/593_C20DisCh.csv',
              'n20degC/607_C20DisCh.csv']

# %%
cellDataObj = cellData(files_name[0], pathname)
cellDataObj.extractData()

cellExtractOCVObj = cellExtractOCV(cellDataObj)
cellExtractOCVObj.runOCV()

plotDataObj = plotData()
plotDataObj.plotComputedOCV(cellExtractOCVObj)
# Out:
# extract data done from 0degC/585_C20DisCh.csv
# extract OCV done
# compute OCV done
# save OCV done

# %%
cellDataObj = cellData(files_name[1], pathname)
cellDataObj.extractData()

cellExtractOCVObj = cellExtractOCV(cellDataObj)
cellExtractOCVObj.runOCV()

plotDataObj = plotData()
plotDataObj.plotComputedOCV(cellExtractOCVObj)
# Out:
# extract data done from 10degC/575_C20DisCh.csv
# extract OCV done
# compute OCV done
# save OCV done

# %%
cellDataObj = cellData(files_name[2], pathname)
cellDataObj.extractData()

cellExtractOCVObj = cellExtractOCV(cellDataObj)
cellExtractOCVObj.runOCV()

plotDataObj = plotData()
plotDataObj.plotComputedOCV(cellExtractOCVObj)
# Out:
# extract data done from 25degC/549_C20DisCh.csv
# extract OCV done
# compute OCV done
# save OCV done

# %%
cellDataObj = cellData(files_name[3], pathname)
cellDataObj.extractData()

cellExtractOCVObj = cellExtractOCV(cellDataObj)
cellExtractOCVObj.runOCV()

plotDataObj = plotData()
plotDataObj.plotComputedOCV(cellExtractOCVObj)
# Out:
# extract data done from 40degC/555_C20DisCh.csv
# extract OCV done
# compute OCV done
# save OCV done

# %%
cellDataObj = cellData(files_name[4], pathname)
cellDataObj.extractData()

cellExtractOCVObj = cellExtractOCV(cellDataObj)
cellExtractOCVObj.runOCV()

plotDataObj = plotData()
plotDataObj.plotComputedOCV(cellExtractOCVObj)
# Out:
# extract data done from n10degC/593_C20DisCh.csv
# extract OCV done
# compute OCV done
# save OCV done

# %%
cellDataObj = cellData(files_name[5], pathname)
cellDataObj.extractData()

cellExtractOCVObj = cellExtractOCV(cellDataObj)
cellExtractOCVObj.runOCV()

plotDataObj = plotData()
plotDataObj.plotComputedOCV(cellExtractOCVObj)
# Out:
# extract data done from n20degC/607_C20DisCh.csv
# extract OCV done
# compute OCV done
# save OCV done
